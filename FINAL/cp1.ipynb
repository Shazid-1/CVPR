# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

import os
import random
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# ignore information messgaes from tensorflow, but we will receieve error messages
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'

# %matplotlib inline

# %% [markdown]
# ### Load dataset

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
ROWS = 3
COLS = 20
i = 0

plt.figure(figsize=(20,3))
for r in range(ROWS):
    for c in range(COLS):
        plt.subplot(ROWS, COLS, i+1)
        plt.imshow(x_train[i], cmap=plt.cm.gray_r)
        
        plt.xticks([])
        plt.yticks([])
        plt.xlabel(y_train[i])
        i += 1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Normalise data

# %%
mean_img = np.mean(X_train, axis=0)
plt.imshow(mean_img.astype('uint8'))

# %%
X_train_norm, X_test_norm = X_train-mean_img, X_test-mean_img

# %%
model = keras.Sequential([
    ## input layer
    keras.Input(shape=(28,28,3)),
    
    ## hidden layers
    layers.Conv2D(filters=32, kernel_size=(5,5), activation='relu'), # input->(32,32) output->(28,28)
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.BatchNormalization(),

    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.BatchNormalization(),

    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.BatchNormalization(),
    
    layers.Flatten(),

    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.BatchNormalization(),

    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    
    ## output layer
    layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_66 (Conv2D)          (None, 24, 24, 32)        2432
#
#  max_pooling2d_48 (MaxPoolin  (None, 12, 12, 32)       0
#  g2D)
#
#  batch_normalization_90 (Bat  (None, 12, 12, 32)       128
#  chNormalization)
#
#  conv2d_67 (Conv2D)          (None, 10, 10, 64)        18496
#
#  max_pooling2d_49 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  batch_normalization_91 (Bat  (None, 5, 5, 64)         256
#  chNormalization)
#
#  conv2d_68 (Conv2D)          (None, 3, 3, 64)          36928
#
#  max_pooling2d_50 (MaxPoolin  (None, 1, 1, 64)         0
#  g2D)
#
#  batch_normalization_92 (Bat  (None, 1, 1, 64)         256
#  chNormalization)
#
#  flatten_16 (Flatten)        (None, 64)                0
#
#  dense_47 (Dense)            (None, 64)                4160
#
#  dropout_30 (Dropout)        (None, 64)                0
#
# ...

# %%
model.compile(
    optimizer='adam', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)
h = model.fit(x=X_train_norm, y=Y_train, epochs=5, validation_split=0.3, batch_size=32)
# Out:
# Epoch 1/5
# WARNING:tensorflow:Model was constructed with shape (None, 28, 28, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 28, 28, 3), dtype=tf.float32, name='input_17'), name='input_17', description="created by layer 'input_17'"), but it was called on an input with incompatible shape (None, 28, 28).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 6
#       1 model.compile(
#       2     optimizer='adam',
#       3     loss='sparse_categorical_crossentropy',
#       4     metrics=['accuracy']
#       5 )
# ----> 6 h = model.fit(x=X_train_norm, y=Y_train, epochs=5, validation_split=0.3, batch_size=32)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
# ...

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(h.history['accuracy'], 'o-', label='train accuracy')
plt.plot(h.history['val_accuracy'], 'o-', label = 'validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(loc='lower right')

plt.subplot(1,2,2)
plt.plot(h.history['loss'], 'o-', label='train loss')
plt.plot(h.history['val_loss'], 'o-', label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend(loc='upper right')

plt.show()

# %%
model.compile(
    optimizer='SGD', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)
h = model.fit(x=X_train_norm, y=Y_train, epochs=5, validation_split=0.3, batch_size=32)

# %%
model.compile(
    optimizer='RMSProp', 
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)
h = model.fit(x=X_train_norm, y=Y_train, epochs=5, validation_split=0.3, batch_size=32)
